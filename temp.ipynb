# %% [markdown]
# # Merge CSVs from turns_with_styles and GPS
# This notebook merges CSV files from `data/turns_with_styles` and `data/GPS` for each subfolder and filename, combining their columns into a single DataFrame per file. The merged files are saved in `data/merged`.

# %%
import os
import pandas as pd

# %%
# Define directories
turns_dir = 'data/turns_with_styles'
gps_dir = 'data/GPS'
output_dir = 'data/merged'
os.makedirs(output_dir, exist_ok=True)

for subfolder in os.listdir(turns_dir):
    turns_subfolder = os.path.join(turns_dir, subfolder)
    gps_subfolder = os.path.join(gps_dir, subfolder)
    output_subfolder = os.path.join(output_dir, subfolder)
    if not os.path.isdir(turns_subfolder):
        continue
    os.makedirs(output_subfolder, exist_ok=True)
    for filename in os.listdir(turns_subfolder):
        if not filename.endswith('.csv'):
            continue
        turns_path = os.path.join(turns_subfolder, filename)
        gps_path = os.path.join(gps_subfolder, filename)
        if not os.path.exists(gps_path):
            print(f"Missing GPS file for {filename}")
            continue
        df_turns = pd.read_csv(turns_path)
        df_gps = pd.read_csv(gps_path)
        # Merge: keep all columns, avoid duplicate columns except the extra ones
        # Assume extra columns are at the end of each file
        # Remove duplicate columns from GPS except the last one (the extra column)
        common_cols = set(df_turns.columns) & set(df_gps.columns)
        gps_extra_col = [col for col in df_gps.columns if col not in common_cols]
        merged = pd.concat([df_turns, df_gps[gps_extra_col]], axis=1)
        merged.to_csv(os.path.join(output_subfolder, filename), index=False)

# %%
import ntplib
from datetime import datetime, timezone

client = ntplib.NTPClient()
response = client.request('ntp.task.gda.pl')  # Polski serwer NTP

# UTC czas
utc_time = datetime.utcfromtimestamp(response.tx_time).replace(tzinfo=timezone.utc)

# Czas w Polsce (uwzględnia czas letni)
import pytz
pl_time = utc_time.astimezone(pytz.timezone('Europe/Warsaw'))

print(pl_time.strftime("%Y-%m-%d %H:%M:%S.%f %Z"))
# Out:
# Fri, 25 Jul 2025 10:19:54 GMT

# %%
import shutil
from pathlib import Path

def merge_csvs_recursive(turns_root, gps_root, output_root):
    turns_root = Path(turns_root)
    gps_root = Path(gps_root)
    output_root = Path(output_root)
    for turns_csv in turns_root.rglob('*.csv'):
        # Build relative path from turns_root
        rel_path = turns_csv.relative_to(turns_root)
        gps_csv = gps_root / rel_path
        output_csv = output_root / rel_path
        if not gps_csv.exists():
            print(f"Missing GPS file for {rel_path}")
            continue
        output_csv.parent.mkdir(parents=True, exist_ok=True)
        df_turns = pd.read_csv(turns_csv)
        df_gps = pd.read_csv(gps_csv)
        # Merge: keep all columns, avoid duplicate columns except the extra ones
        common_cols = set(df_turns.columns) & set(df_gps.columns)
        gps_extra_col = [col for col in df_gps.columns if col not in common_cols]
        merged = pd.concat([df_turns, df_gps[gps_extra_col]], axis=1)
        merged.to_csv(output_csv, index=False)

# Usage
merge_csvs_recursive('data/turns_with_styles', 'data/GPS', 'data/merged')

# %%
def check_and_merge(turns_csv, gps_csv, output_csv):
    df_turns = pd.read_csv(turns_csv)
    df_gps = pd.read_csv(gps_csv)
    # Check number of rows
    if len(df_turns) != len(df_gps):
        print(f"Row count mismatch: {turns_csv} ({len(df_turns)}) vs {gps_csv} ({len(df_gps)})")
        return False
    # Check first and last index (assume index is the first column)
    turns_idx = df_turns.iloc[:,0]
    gps_idx = df_gps.iloc[:,0]
    if not (turns_idx.iloc[0] == gps_idx.iloc[0] and turns_idx.iloc[-1] == gps_idx.iloc[-1]):
        print(f"Index mismatch: {turns_csv} vs {gps_csv}")
        return False
    # Merge: keep all columns, avoid duplicate columns except the extra ones
    common_cols = set(df_turns.columns) & set(df_gps.columns)
    gps_extra_col = [col for col in df_gps.columns if col not in common_cols]
    merged = pd.concat([df_turns, df_gps[gps_extra_col]], axis=1)
    # Check output DataFrame index
    merged_idx = merged.iloc[:,0]
    if not (merged_idx.iloc[0] == turns_idx.iloc[0] and merged_idx.iloc[-1] == turns_idx.iloc[-1]):
        print(f"Output index mismatch in {output_csv}")
        return False
    merged.to_csv(output_csv, index=False)
    return True

def merge_csvs_recursive_checked(turns_root, gps_root, output_root):
    turns_root = Path(turns_root)
    gps_root = Path(gps_root)
    output_root = Path(output_root)
    for turns_csv in turns_root.rglob('*.csv'):
        rel_path = turns_csv.relative_to(turns_root)
        gps_csv = gps_root / rel_path
        output_csv = output_root / rel_path
        if not gps_csv.exists():
            print(f"Missing GPS file for {rel_path}")
            continue
        output_csv.parent.mkdir(parents=True, exist_ok=True)
        check_and_merge(turns_csv, gps_csv, output_csv)

# Usage
merge_csvs_recursive_checked('data/turns_with_styles', 'data/GPS', 'data/merged')
# Out:
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-22/6.csv vs data/GPS/HONOR_8X/2024-03-22/6.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-22/7.csv vs data/GPS/HONOR_8X/2024-03-22/7.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-22/5.csv vs data/GPS/HONOR_8X/2024-03-22/5.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-22/4.csv vs data/GPS/HONOR_8X/2024-03-22/4.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-22/1.csv vs data/GPS/HONOR_8X/2024-03-22/1.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-22/3.csv vs data/GPS/HONOR_8X/2024-03-22/3.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-22/2.csv vs data/GPS/HONOR_8X/2024-03-22/2.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-22/10.csv vs data/GPS/HONOR_8X/2024-03-22/10.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-22/9.csv vs data/GPS/HONOR_8X/2024-03-22/9.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-22/8.csv vs data/GPS/HONOR_8X/2024-03-22/8.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-02-24/2_sp.csv vs data/GPS/HONOR_8X/2024-02-24/2_sp.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-20/10.csv vs data/GPS/HONOR_8X/2024-03-20/10.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-20/11.csv vs data/GPS/HONOR_8X/2024-03-20/11.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-20/13.csv vs data/GPS/HONOR_8X/2024-03-20/13.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-20/12.csv vs data/GPS/HONOR_8X/2024-03-20/12.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-20/9.csv vs data/GPS/HONOR_8X/2024-03-20/9.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-03-20/8.csv vs data/GPS/HONOR_8X/2024-03-20/8.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-02-17/6.csv vs data/GPS/HONOR_8X/2024-02-17/6.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-02-17/5.csv vs data/GPS/HONOR_8X/2024-02-17/5.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-02-17/4.csv vs data/GPS/HONOR_8X/2024-02-17/4.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-02-17/1.csv vs data/GPS/HONOR_8X/2024-02-17/1.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-02-17/3.csv vs data/GPS/HONOR_8X/2024-02-17/3.csv
# Index mismatch: data/turns_with_styles/HONOR_8X/2024-02-17/2.csv vs data/GPS/HONOR_8X/2024-02-17/2.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/6.csv vs data/GPS/huawei_mate/2024-02-25/6.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/7.csv vs data/GPS/huawei_mate/2024-02-25/7.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/5.csv vs data/GPS/huawei_mate/2024-02-25/5.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/4.csv vs data/GPS/huawei_mate/2024-02-25/4.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/21_sp.csv vs data/GPS/huawei_mate/2024-02-25/21_sp.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/1.csv vs data/GPS/huawei_mate/2024-02-25/1.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/3.csv vs data/GPS/huawei_mate/2024-02-25/3.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/2.csv vs data/GPS/huawei_mate/2024-02-25/2.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/23.csv vs data/GPS/huawei_mate/2024-02-25/23.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/22.csv vs data/GPS/huawei_mate/2024-02-25/22.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/20.csv vs data/GPS/huawei_mate/2024-02-25/20.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/25.csv vs data/GPS/huawei_mate/2024-02-25/25.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/19.csv vs data/GPS/huawei_mate/2024-02-25/19.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/18.csv vs data/GPS/huawei_mate/2024-02-25/18.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/26.csv vs data/GPS/huawei_mate/2024-02-25/26.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/27.csv vs data/GPS/huawei_mate/2024-02-25/27.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/16.csv vs data/GPS/huawei_mate/2024-02-25/16.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/17.csv vs data/GPS/huawei_mate/2024-02-25/17.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/15.csv vs data/GPS/huawei_mate/2024-02-25/15.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/14.csv vs data/GPS/huawei_mate/2024-02-25/14.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/28.csv vs data/GPS/huawei_mate/2024-02-25/28.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/10.csv vs data/GPS/huawei_mate/2024-02-25/10.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/11.csv vs data/GPS/huawei_mate/2024-02-25/11.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/13.csv vs data/GPS/huawei_mate/2024-02-25/13.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/12.csv vs data/GPS/huawei_mate/2024-02-25/12.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/24_sp.csv vs data/GPS/huawei_mate/2024-02-25/24_sp.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/9.csv vs data/GPS/huawei_mate/2024-02-25/9.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-02-25/8.csv vs data/GPS/huawei_mate/2024-02-25/8.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-03-17/6.csv vs data/GPS/huawei_mate/2024-03-17/6.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-03-17/7.csv vs data/GPS/huawei_mate/2024-03-17/7.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-03-17/5.csv vs data/GPS/huawei_mate/2024-03-17/5.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-03-17/4.csv vs data/GPS/huawei_mate/2024-03-17/4.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-03-17/1.csv vs data/GPS/huawei_mate/2024-03-17/1.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-03-17/3.csv vs data/GPS/huawei_mate/2024-03-17/3.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-03-17/2.csv vs data/GPS/huawei_mate/2024-03-17/2.csv
# Index mismatch: data/turns_with_styles/huawei_mate/2024-03-17/8.csv vs data/GPS/huawei_mate/2024-03-17/8.csv
